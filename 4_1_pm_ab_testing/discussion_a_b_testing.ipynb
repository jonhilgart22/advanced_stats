# %% [markdown]
# What is hard to A/B test? <br> What can NOT you A/B test?
# -----
#
# <center><img src="http://s.quickmeme.com/img/ea/eae79cecef0a1bc06291c4bec44994bfb03f1c982af7beb96a0a6398fec94143.jpg" width="550"/></center>

# %% [markdown]
# <center><img src="images/a_b_test_everything.jpg" height="500"/></center>

# %% [markdown]
# <br>
# <br>
# <br>
